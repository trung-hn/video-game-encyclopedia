# %% [markdown]
# ### This script will run over all files in `/data/game_info/` and write to a csv in `/data/game_info.csv`

# %%
import json
import os
from pprint import pprint
import csv
import pandas as pd
pd.set_option("display.max_columns", 50)
pd.set_option("display.max_rows", 20)

# %%
# Output CSV file
csv_file = open(r"../data/game_info.csv", "w", encoding="utf8")
csv_writer = csv.writer(csv_file, lineterminator="\n")

# Loop through each file
for i, file in enumerate(os.listdir(r"../data/game_info/")):
    with open(fr"../data/game_info/{file}", "r", encoding="utf8") as f:
        data = json.load(f)

    # Change all list into string seperated by "||"
    for key, val in data.items():
        if isinstance(val, list):
            data[key] = "||".join(v.replace("||", "|") for v in val)
    
    # Split this data into different columns and delete it
    if data["added_by_status"]:
        for status in ("yet", "owned", "beaten", "toplay", "dropped", "playing"):
            data[f"added_status_{status}"] = data["added_by_status"].get(status, 0)
    else:
        for status in ("yet", "owned", "beaten", "toplay", "dropped", "playing"):
            data[f"added_status_{status}"] = 0
    del data["added_by_status"]
    
    # Write to file
    if i == 0: csv_writer.writerow(data.keys())
    csv_writer.writerow(data.values())
    
    # Verbose Notification
    if i and i%10000 == 0: print(f"Finished {i} files")
print("Finished everything")

# Save file
csv_file.close()
# Out:
# Finished 10000 files
# Finished 20000 files
# Finished 30000 files
# Finished 40000 files
# Finished 50000 files
# Finished 60000 files
# Finished 70000 files
# Finished 80000 files
# Finished 90000 files
# Finished 100000 files
# Finished 110000 files
# Finished 120000 files
# Finished 130000 files
# Finished 140000 files
# Finished 150000 files
# Finished 160000 files
# Finished 170000 files
# Finished 180000 files
# Finished 190000 files
# Finished 200000 files
# Finished 210000 files
# Finished 220000 files
# Finished 230000 files
# Finished 240000 files
# Finished 250000 files
# Finished 260000 files
# Finished 270000 files
# Finished 280000 files
# Finished 290000 files
# Finished 300000 files
# Finished 310000 files
# Finished 320000 files
# Finished 330000 files
# Finished 340000 files
# Finished everything

# %% [markdown]
# ### Open file with pandas to check the result

# %%
df = pd.read_csv(open(r"../data/game_info.csv", "r", encoding="utf8"))
df
# Out:
#             id                  slug                    name  metacritic  \
# 0            1        dgeneration-hd         D/Generation HD         NaN
# 1           10               g-prime   G Prime Into The Rain         NaN
# 2          100          land-sliders            Land Sliders         NaN
# 3         1000            pixel-gear              Pixel Gear         NaN
# 4        10000        gods-and-idols          Gods and Idols         NaN
# 5       100000          plague-venue            Plague venue         NaN
# 6       100001  the-moon-sliver-itch  The Moon Sliver (itch)         NaN
# 7       100002            red-entity              Red Entity         NaN
# 8       100003               rollman          Rollman (itch)         NaN
# 9       100004         hippiesvscops           HippiesVsCops         NaN
# ...        ...                   ...                     ...         ...
# 345657    9999      pixel-privateers        Pixel Privateers         NaN
# 345658   99990            about-face              about-face         NaN
# 345659   99991          light-cycles            Light Cycles         NaN
# 345660   99992     scrapjunk-courier       Scrapjunk Courier         NaN
# 345661   99993     primal-fears-itch     Primal Fears (itch)         NaN
# 345662   99994          holy-or-dead            Holy or Dead         NaN
# 345663   99995     airstrike-hd-demo       Airstrike HD Demo         NaN
# 345664   99997        uranias-mirror         Urania's Mirror         NaN
# 345665   99998            simucities              Simucities         NaN
# 345666   99999        pocket-assault   Pocket Assault (itch)         NaN
#
#           released    tba              updated  \
# 0       2015-10-23  False  2019-09-17T11:58:57
# 1       2016-01-06  False  2019-11-06T23:04:19
# 345663                                                 PC
# 345664                                                 PC
# 345665                                                 PC
# 345666                                                 PC
#
#                                               developers  \
# 0       West Coast Software||West Coast Software Limited
# 1                                             Soma Games
# 2                                  Prettygreat Pty. Ltd.
# 3              Oasis Games Limited||Geronimo Interactive
# 4                                             Viking Tao
# 5                                   Alexander Ponomariov
# 6                                        David Szymanski
# 7                                                   woof
# 8                                                rollman
# 9                                          alegaroficial
# ...                                                  ...
# 345657                                      Quadro Delta
# 345658                                           Peltast
# 345659                                          Clabbage
# 345660                                             reBTF
# 345661                                            DnSdev
# 345662                                           Ralidon
# 345663                           Fifth Dimension Company
# 345664                                        sneakthief
# 345665                                         keypixels
# 345666                                 Carsten_Ostermann
#
#                                            genres  \
# 0                               Adventure||Puzzle
# 1                               Simulation||Indie
# 2                               Adventure||Arcade
# 3                                   Action||Indie
# 4            RPG||Strategy||Massively Multiplayer
# 5                                             NaN
# 6                                       Adventure
# 7                                 Action||Shooter
# 8                                       Adventure
# 9                                        Strategy
# ...                                           ...
# 345657  Action||Adventure||RPG||Simulation||Indie
# 345658                                 Platformer
# 345659                                     Action
# 345660                                   Strategy
# 345661                                     Action
# 345662                                        NaN
# 345663                                     Action
# 345664                                  Adventure
# 345665                                        NaN
# 345666                                    Shooter
#
#                                                publishers   esrb_rating  \
# 0        West Coast Software||West Coast Software Limited  Everyone 10+
# 1       Code-Monkeys||Code-Monkeys LLC||Immanitas Ente...      Everyone
# 2                                   Prettygreat Pty. Ltd.  Everyone 10+
# 3                                    Geronimo Interactive          Teen
# 4                                              Viking Tao           NaN
# 5                                                     NaN           NaN
# 6                                                     NaN           NaN
# 7                                                     NaN           NaN
# 8                                                     NaN           NaN
# 9                                                     NaN           NaN
# ...                                                   ...           ...
# 345657                                           Re-Logic           NaN
# 345658                                                NaN           NaN
# 345659                                                NaN           NaN
# 345660                                                NaN           NaN
# 345661                                                NaN           NaN
# 345662                                                NaN           NaN
# 345663                                                NaN           NaN
# 345664                                                NaN           NaN
# 345665                                                NaN           NaN
# 345666                                                NaN           NaN
#
#         added_status_yet  added_status_owned  added_status_beaten  \
# 0                      3                  70                    0
# 1                      0                  39                    0
# 2                      0                   0                    1
# 3                      0                   0                    0
# 4                      1                  57                    0
# 5                      0                   0                    0
# 6                      0                   0                    0
# 7                      0                   0                    0
# 8                      0                   0                    0
# 9                      0                   0                    0
# ...                  ...                 ...                  ...
# 345657                 1                  29                    0
# 345658                 0                   0                    0
# 345659                 0                   0                    0
# 345660                 0                   0                    0
# 345661                 0                   0                    0
# 345662                 0                   0                    0
# 345663                 0                   0                    0
# 345664                 0                   0                    0
# 345665                 0                   0                    0
# 345666                 0                   0                    0
#
#         added_status_toplay  added_status_dropped  added_status_playing
# 0                         2                     0                     0
# 1                         1                     0                     0
# 2                         1                     1                     0
# 3                         2                     0                     0
# 4                         1                     0                     0
# 5                         0                     0                     0
# 6                         0                     0                     0
# 7                         0                     0                     0
# 8                         0                     0                     0
# 9                         0                     0                     0
# ...                     ...                   ...                   ...
# 345657                    2                     1                     0
# 345658                    0                     0                     0
# 345659                    0                     0                     0
# 345660                    0                     0                     0
# 345661                    0                     0                     0
# 345662                    0                     0                     0
# 345663                    0                     0                     0
# 345664                    0                     0                     0
# 345665                    0                     0                     0
# 345666                    0                     0                     0
#
# [345667 rows x 27 columns]
